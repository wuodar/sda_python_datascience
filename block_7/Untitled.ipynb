# %% [markdown]
# Pierwsza komórka powinna być poświęcona na importy

# %%
import math

# %% [markdown]
# # asdadsdadasd

# %% [markdown]
# Po importach mogą wsytępować dowolne elementy, funkcje/klasy/wywołania

# %%
def get_absolute_float(value: float):
    return math.fabs(value)

# %%
get_absolute_float(-10)

# %% [markdown]
# ## HEADING
#
# ### 1 Something
# ### 2 Another
#
# [some_url](https://www.google.com)
#
# _abc_
# **abc**
#
# ```python
# def get_absolute_float(value):
#     return math.fabs(value)
# ```
